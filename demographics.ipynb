# %%
import pandas as pd
from uszipcode import SearchEngine
import numpy as np

# %%
houston_zip_codes = pd.read_csv('./Data/houston_cleaned_zipcodes.csv')

# %%
houston_zip_codes.head()
# Out:
#    Zip_Code                               Name
# 0     77002                  Downtown, Midtown
# 1     77003                      East Downtown
# 2     77004  South Central, Greater Third Ward
# 3     77005              West University Place
# 4     77006                Montrose, Hyde Park

# %%
dfw_zipcodes = pd.read_csv('./Data/dfw_cleaned_zipcodes.csv')

# %%
dfw_zipcodes.head()
# Out:
#    Zip_Code               Name
# 0     75001            Addison
# 1     75002         West Allen
# 2     75006  Central Carrolton
# 3     75007   North Carrollton
# 4     75009             Celina

# %%
def get_demographics(zipcode_df):
    demos = []
    for zipcode in zipcode_df['Zip_Code']:
        full_zipcode_db = SearchEngine(simple_zipcode = False)
        zipcode_demographics = full_zipcode_db.by_zipcode(zipcode)
        zipcode_demographics = zipcode_demographics.to_dict()
        keys = ['lat', 'lng', 'population', 'median_household_income', 'median_home_value']
        demo_list = [zipcode_demographics.get(key) for key in keys]
        education_column_names = ["Less Than High School", "High School Graduate", "Associate's Degree", "Bachelor's Degree", "Master's Degree", "Professional Degree", "Doctorate Degree"]
        education_values = [zipcode_demographics['educational_attainment_for_population_25_and_over'][0]['values'][i]['y'] for i in range(len(education_column_names))]
        demo_list = demo_list + education_values
        keys = keys + education_column_names
        demos.append(demo_list)
    df = pd.DataFrame(demos, columns = keys)
    df = pd.concat([zipcode_df, df], axis = 1)
    return df

# %%
dallas_df = get_demographics(dfw_zipcodes)

# %%
dallas_df.head()
# Out:
#    Zip_Code               Name    lat    lng  population  \
# 0     75001            Addison  32.96 -96.84       12414
# 1     75002         West Allen  33.08 -96.61       63140
# 2     75006  Central Carrolton  32.95 -96.89       46364
# 3     75007   North Carrollton  33.00 -96.90       51624
# 4     75009             Celina  33.30 -96.80        8785
#
#    median_household_income  median_home_value  Less Than High School  \
# 0                  57633.0           258200.0                    919
# 1                  91632.0           186100.0                   2136
# 2                  56985.0           146800.0                   7814
# 3                  78934.0           169400.0                   3485
# 4                  87581.0           190500.0                    420
#
#    High School Graduate  Associate's Degree  Bachelor's Degree  \
# 0                  3655                 381               3318
# 1                 16961                3465              12670
# 2                 11857                2041               6459
# 3                 14680                2810               9935
# 4                  2991                 608               1230
#
#    Master's Degree  Professional Degree  Doctorate Degree
# 0             1439                  232                34
# 1             4453                  625               434
# 2             2326                  315                80
# 3             2614                  511               416
# 4              393                   35                18

# %%
def education_percentage(df):
    education_columns = df[['Less Than High School', 'High School Graduate', "Associate's Degree", "Bachelor's Degree", "Master's Degree", 'Professional Degree', 'Doctorate Degree']]
    education_percentages = education_columns.div(education_columns.sum(axis = 1), axis = 0)
    df.update(education_percentages)
    return df

# %%
dallas_df = education_percentage(dallas_df)

# %%
dallas_df.head()
# Out:
#    Zip_Code               Name    lat    lng  population  \
# 0     75001            Addison  32.96 -96.84       12414
# 1     75002         West Allen  33.08 -96.61       63140
# 2     75006  Central Carrolton  32.95 -96.89       46364
# 3     75007   North Carrollton  33.00 -96.90       51624
# 4     75009             Celina  33.30 -96.80        8785
#
#    median_household_income  median_home_value  Less Than High School  \
# 0                  57633.0           258200.0               0.092103
# 1                  91632.0           186100.0               0.052425
# 2                  56985.0           146800.0               0.252946
# 3                  78934.0           169400.0               0.101158
# 4                  87581.0           190500.0               0.073749
#
#    High School Graduate  Associate's Degree  Bachelor's Degree  \
# 0              0.366306            0.038184           0.332532
# 1              0.416282            0.085043           0.310966
# 2              0.383821            0.066069           0.209083
# 3              0.426112            0.081565           0.288381
# 4              0.525198            0.106760           0.215979
#
#    Master's Degree  Professional Degree  Doctorate Degree
# 0         0.144217             0.023251          0.003407
# 1         0.109292             0.015340          0.010652
# 2         0.075295             0.010197          0.002590
# 3         0.075876             0.014833          0.012075
# 4         0.069008             0.006146          0.003161

# %%
dallas_df.to_csv('./Data/dfw_demographics.csv', index = False)

# %%
houston_df = get_demographics(houston_zip_codes)

# %%
houston_df.head()
# Out:
#    Zip_Code                               Name    lat    lng  population  \
# 0     77002                  Downtown, Midtown  29.75 -95.37       16793
# 1     77003                      East Downtown  29.75 -95.35       10508
# 2     77004  South Central, Greater Third Ward  29.72 -95.38       32692
# 3     77005              West University Place  29.72 -95.42       25528
# 4     77006                Montrose, Hyde Park  29.74 -95.39       19664
#
#    median_household_income  median_home_value  Less Than High School  \
# 0                  64093.0           208600.0                   2413
# 1                  36412.0           162600.0                   2191
# 2                  41983.0           191700.0                   2998
# 3                 159732.0           754000.0                    262
# 4                  67458.0           327300.0                    557
#
#    High School Graduate  Associate's Degree  Bachelor's Degree  \
# 0                  3778                 446               1389
# 1                  2544                 266               1141
# 2                  6567                 769               4387
# 3                  1997                 661               5473
# 4                  4375                 512               5607
#
#    Master's Degree  Professional Degree  Doctorate Degree
# 0              651                  197               206
# 1              421                  202               122
# 2             2607                 1146               540
# 3             3716                 3008              1224
# 4             2845                 1674               969

# %%
houston_df = education_percentage(houston_df)

# %%
houston_df.head()
# Out:
#    Zip_Code                               Name    lat    lng  population  \
# 0     77002                  Downtown, Midtown  29.75 -95.37       16793
# 1     77003                      East Downtown  29.75 -95.35       10508
# 2     77004  South Central, Greater Third Ward  29.72 -95.38       32692
# 3     77005              West University Place  29.72 -95.42       25528
# 4     77006                Montrose, Hyde Park  29.74 -95.39       19664
#
#    median_household_income  median_home_value  Less Than High School  \
# 0                  64093.0           208600.0               0.265749
# 1                  36412.0           162600.0               0.318136
# 2                  41983.0           191700.0               0.157673
# 3                 159732.0           754000.0               0.016033
# 4                  67458.0           327300.0               0.033678
#
#    High School Graduate  Associate's Degree  Bachelor's Degree  \
# 0              0.416079            0.049119           0.152974
# 1              0.369392            0.038623           0.165674
# 2              0.345377            0.040444           0.230725
# 3              0.122208            0.040450           0.334924
# 4              0.264526            0.030957           0.339017
#
#    Master's Degree  Professional Degree  Doctorate Degree
# 0         0.071696             0.021696          0.022687
# 1         0.061130             0.029331          0.017715
# 2         0.137109             0.060271          0.028400
# 3         0.227403             0.184077          0.074904
# 4         0.172018             0.101215          0.058589

# %%
houston_df.to_csv('./Data/houston_demographics.csv', index = False)
